# %% [markdown]
# <a href="https://colab.research.google.com/github/Srayoshi-Mirza/Popular-programming-language/blob/main/Data_Analysis_of_Most_Popular_Programming_Language.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly==4.14.3
# Out:
# Requirement already satisfied: plotly==4.14.3 in /usr/local/lib/python3.10/dist-packages (4.14.3)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from plotly==4.14.3) (1.3.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from plotly==4.14.3) (1.16.0)

# %%
# !pip install palettable
# Out:
# Collecting palettable
#   Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: palettable
# Successfully installed palettable-3.3.3

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import animation
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import seaborn as sns
import plotly.express as px
from datetime import datetime
from palettable.matplotlib import Magma_20_r, Magma_10_r

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Srayoshi-Mirza/Popular-programming-language/main/Popularity%20of%20Programming%20Languages%20from%202004%20to%202023.csv")
data.head()
# Out:
#              Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  \
# 0       July 2004  0.34  0.36  10.01  4.68   0.42   0.0           2.80  0.0
# 1     August 2004  0.35  0.36   9.74  4.96   0.46   0.0           2.65  0.0
# 2  September 2004  0.41  0.41   9.59  5.04   0.51   0.0           2.64  0.0
# 3    October 2004  0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0
# 4   November 2004  0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0
#
#    Groovy  ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  \
# 0    0.03  ...        0.16    2.51  0.39  0.33  0.24   0.17    0.0
# 1    0.07  ...        0.15    2.62  0.40  0.40  0.19   0.17    0.0
# 2    0.08  ...        0.08    2.71  0.40  0.41  0.17   0.13    0.0
# 3    0.09  ...        0.12    2.91  0.42  0.46  0.12   0.14    0.0
# 4    0.07  ...        0.12    2.83  0.41  0.44  0.17   0.15    0.0
#
#    TypeScript   VBA  Visual Basic
# 0         0.0  1.43          8.50
# 1         0.0  1.45          8.51
# 2         0.0  1.54          8.38
# 3         0.0  1.61          8.46
# 4         0.0  1.50          8.21
#
# [5 rows x 30 columns]

# %% [markdown]
# # **Data Cleaning**

# %%
data.isna().sum()
# Out:
# Date             0
# Abap             0
# Ada              0
# C/C++            0
# C#               0
# Cobol            0
# Dart             0
# Delphi/Pascal    0
# Go               0
# Groovy           0
# Haskell          0
# Java             0
# JavaScript       0
# Julia            0
# Kotlin           0
# Lua              0
# Matlab           0
# Objective-C      0
# Perl             0
# PHP              0
# Powershell       0
# Python           0
# R                0
# Ruby             0
# Rust             0
# Scala            0
# Swift            0
# TypeScript       0
# VBA              0
# Visual Basic     0
# dtype: int64

# %%
data["Date"] = pd.to_datetime(data["Date"])
data.head()
# Out:
#         Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  \
# 0 2004-07-01  0.34  0.36  10.01  4.68   0.42   0.0           2.80  0.0
# 1 2004-08-01  0.35  0.36   9.74  4.96   0.46   0.0           2.65  0.0
# 2 2004-09-01  0.41  0.41   9.59  5.04   0.51   0.0           2.64  0.0
# 3 2004-10-01  0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0
# 4 2004-11-01  0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0
#
#    Groovy  ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  \
# 0    0.03  ...        0.16    2.51  0.39  0.33  0.24   0.17    0.0
# 1    0.07  ...        0.15    2.62  0.40  0.40  0.19   0.17    0.0
# 2    0.08  ...        0.08    2.71  0.40  0.41  0.17   0.13    0.0
# 3    0.09  ...        0.12    2.91  0.42  0.46  0.12   0.14    0.0
# 4    0.07  ...        0.12    2.83  0.41  0.44  0.17   0.15    0.0
#
#    TypeScript   VBA  Visual Basic
# 0         0.0  1.43          8.50
# 1         0.0  1.45          8.51
# 2         0.0  1.54          8.38
# 3         0.0  1.61          8.46
# 4         0.0  1.50          8.21
#
# [5 rows x 30 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           227 non-null    datetime64[ns]
#  1   Abap           227 non-null    float64
#  2   Ada            227 non-null    float64
#  3   C/C++          227 non-null    float64
#  4   C#             227 non-null    float64
#  5   Cobol          227 non-null    float64
#  6   Dart           227 non-null    float64
#  7   Delphi/Pascal  227 non-null    float64
#  8   Go             227 non-null    float64
#  9   Groovy         227 non-null    float64
#  10  Haskell        227 non-null    float64
#  11  Java           227 non-null    float64
#  12  JavaScript     227 non-null    float64
#  13  Julia          227 non-null    float64
#  14  Kotlin         227 non-null    float64
#  15  Lua            227 non-null    float64
#  16  Matlab         227 non-null    float64
#  17  Objective-C    227 non-null    float64
#  18  Perl           227 non-null    float64
#  19  PHP            227 non-null    float64
#  20  Powershell     227 non-null    float64
#  21  Python         227 non-null    float64
#  22  R              227 non-null    float64
#  23  Ruby           227 non-null    float64
#  24  Rust           227 non-null    float64
#  25  Scala          227 non-null    float64
#  26  Swift          227 non-null    float64
#  27  TypeScript     227 non-null    float64
#  28  VBA            227 non-null    float64
#  29  Visual Basic   227 non-null    float64
# dtypes: datetime64[ns](1), float64(29)
# memory usage: 53.3 KB

# %%
data.describe()
# Out:
#              Abap         Ada       C/C++          C#       Cobol        Dart  \
# count  227.000000  227.000000  227.000000  227.000000  227.000000  227.000000
# mean     0.489692    0.361542    8.113348    7.496784    0.368194    0.176608
# std      0.107508    0.198476    1.774062    1.232928    0.072104    0.239022
# min      0.320000    0.090000    5.480000    4.680000    0.180000    0.000000
# 25%      0.400000    0.220000    6.800000    6.640000    0.320000    0.000000
# 50%      0.480000    0.320000    7.940000    7.200000    0.360000    0.090000
# 75%      0.560000    0.390000    8.675000    8.440000    0.405000    0.180000
# max      0.760000    1.020000   12.890000    9.940000    0.560000    0.880000
#
#        Delphi/Pascal          Go      Groovy     Haskell  ...  Powershell  \
# count     227.000000  227.000000  227.000000  227.000000  ...  227.000000
# mean        0.960661    0.476344    0.343128    0.292952  ...    0.650088
# std         0.770689    0.605488    0.142274    0.043371  ...    0.345986
# min         0.000000    0.000000    0.030000    0.200000  ...    0.010000
# 25%         0.290000    0.030000    0.285000    0.260000  ...    0.330000
# 50%         0.700000    0.090000    0.380000    0.290000  ...    0.740000
# 75%         1.625000    0.885000    0.440000    0.330000  ...    0.910000
# max         2.800000    2.130000    0.570000    0.390000  ...    1.260000
#
#            Python           R        Ruby        Rust       Scala       Swift  \
# count  227.000000  227.000000  227.000000  227.000000  227.000000  227.000000
# mean    13.558106    2.310396    1.986872    0.362599    0.582687    1.192203
# std      9.638546    1.406341    0.742304    0.456221    0.405719    1.330639
# min      2.510000    0.380000    0.330000    0.020000    0.020000    0.000000
# 25%      6.215000    1.000000    1.350000    0.070000    0.180000    0.000000
# 50%      9.860000    2.120000    2.290000    0.160000    0.560000    0.000000
# 75%     23.325000    3.795000    2.620000    0.405000    0.965000    2.380000
# max     31.410000    4.600000    2.940000    2.110000    1.350000    3.530000
#
#        TypeScript         VBA  Visual Basic
# count  227.000000  227.000000    227.000000
# mean     0.679868    1.606256      3.378414
# std      0.869228    0.365879      2.281362
# min      0.000000    0.860000      0.530000
# 25%      0.020000    1.390000      1.140000
# 50%      0.110000    1.550000      3.020000
# 75%      1.480000    1.730000      5.325000
# max      2.880000    2.620000      8.510000
#
# [8 rows x 29 columns]

# %%
# set global variable for color palette (plots) and grid style
PALETTE = "magma_r" # my favourite palettes: flare, CMRmap_r, magma_r
sns.set(style="darkgrid")

# function that generates n color values out of defined PALETTE
def generate_color_series(n):
    segments = cm.get_cmap(PALETTE, n)
    return segments(range(n))

# %%
data_mean_list = []

for col in data:
    if col == "Date":
        pass
    else:
        data_mean_list.append([col, data[col].mean()])

data_mean = pd.DataFrame(data_mean_list, columns = ["language", "mean"])
data_mean = data_mean.sort_values(by=["mean"], ascending=False)

plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.title("Mean popularity of languages")
sns.barplot(data=data_mean, x="mean", y="language", palette=generate_color_series(28))
plt.xlabel("Mean popularity in %")
plt.ylabel("Programming language")
# Out:
# <ipython-input-12-32a41585e8ef>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   segments = cm.get_cmap(PALETTE, n)
# Text(0, 0.5, 'Programming language')

# %%
plt.subplot(1, 2, 2)
data_mean_top10 = data_mean.nlargest(10, "mean")
plt.title("Top 10 mean popular languages")
donut_top10 = plt.Circle( (0,0), 0.7, color='white')
plt.pie(data_mean_top10["mean"],labels=data_mean_top10["language"], wedgeprops = {"linewidth": 5, "edgecolor": "white"}, colors=generate_color_series(10))
p = plt.gcf()
p.gca().add_artist(donut_top10)

plt.show()
# Out:
# <ipython-input-12-32a41585e8ef>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   segments = cm.get_cmap(PALETTE, n)

# %%
top10_linechart_color = generate_color_series(10)
plt.figure(figsize=(14, 8))
for index, element in enumerate(data_mean["language"]):
    plt.plot(data["Date"], data[element], color=top10_linechart_color[index], label=element)
    plt.legend()
    if index == 9:
        break
plt.title("Popularity of languages")
plt.xlabel("Year")
plt.ylabel("Mean popularity in %")

plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
# Out:
# <ipython-input-12-32a41585e8ef>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   segments = cm.get_cmap(PALETTE, n)
